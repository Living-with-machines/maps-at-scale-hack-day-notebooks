# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-

import mysql.connector
from mysql.connector import Error
import psycopg2
import psycopg2.extras
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from timeit import default_timer as timer
import geopandas as gpd
from shapely.geometry import shape
from shapely.geometry import Point
from descartes import PolygonPatch
from geopandas.tools import sjoin
from tqdm import tqdm_notebook as tqdm
import pandas as pd
import itertools
import haversine
import getpass
import os.path
import fiona
import json
import glob
import ast
import csv
import re
import itertools
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
import pandas as pd

# %% [markdown]
# ### Start the gazetteer DB server
#
# Make sure you change your credentials. This is to connect to the DB locally in MySQL:

# %%
# read Credentials from the credentials.json file
credentials_config = dict()
with open('../credentials.json') as f:
    credentials_config = json.load(f)

# %%
credentials_config['lwmrelationaldb']['password'] = getpass.getpass(prompt='Enter your password: ')
# Out:
# Enter your password: ········

# %%
# Construct connection string
psql_conn_string =\
    "host={0} user={1} dbname={2} password={3} sslmode={4} sslrootcert={5}".format(
                credentials_config['lwmrelationaldb']['host'], 
                credentials_config['lwmrelationaldb']['user'], 
                'gazetteer', 
                credentials_config['lwmrelationaldb']['password'], 
                credentials_config['lwmrelationaldb']['sslmode'], 
                credentials_config['lwmrelationaldb']['sslrootcert'])

# %%
gazDB = psycopg2.connect(psql_conn_string) 
print("Connection established!")

cursorGaz = gazDB.cursor(cursor_factory=psycopg2.extras.DictCursor)
# Out:
# Connection established!

# %% [markdown]
# ### Read GB1900

# %%
gb1900df = pd.DataFrame()
with open("/Users/mcollardanuy/Documents/workspace/toponymResolution/GIR2019/gb1900_analysis/gb1900_gazetteer_complete_july_2018.csv", encoding='UTF-16') as f:
    gb1900df = pd.read_csv(f)
# Out:
# /Users/mcollardanuy/anaconda3/envs/GIS/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
gb1900df.head()
# Out:
#                      pin_id               final_text   nation local_authority  \
# 0  52b34d8b695fe90005004e1e  F. P.                    Wales    Powys
# 1  5800a6b92c66dcab3d061796  Parly. & Munl Boro. By.  England  City of London
# 2  5800a6782c66dcab3d061786  S. Ps.                   England  City of London
# 3  57f684f42c66dcab3d01c0dd  Southwark Bridge Stairs  England  City of London
# 4  57f685002c66dcab3d01c0e9  St. Paul's Pier          England  City of London
#
#       parish      osgb_east     osgb_north   latitude  longitude notes
# 0  Llansilin  320836.712742  327820.182715  52.842050 -3.176744   NaN
# 1  NaN        531794.825962  180705.741898  51.509918 -0.102246   NaN
# 2  NaN        531736.217116  180725.027730  51.510105 -0.103083   NaN
# 3  NaN        532199.584123  180696.934434  51.509744 -0.096420   NaN
# 4  NaN        531987.486097  180745.664556  51.510232 -0.099456   NaN

# %% [markdown]
# ### Create an approximately British Wiki Gazetteer

# %%
start_time = timer()

# %%
def find_british_locations(cursorGaz, timer):
    print('Start locations SQL query: {} seconds'.format(timer() - start_time))

    cursorGaz.execute("""
            SELECT * FROM location
            WHERE lat > 50.0
            AND lat < 62.0
            AND lon > -14.0
            AND lon < 3.0
        """)
    results = cursorGaz.fetchall()
    
    main_id = []
    wiki_title = []
    wiki_lat = []
    wiki_lon = []
    page_len = []
    type_loc = []
    population = []
    for r in results:
        main_id.append(r['id'])
        wiki_title.append(r['wiki_title'])
        page_len.append(r['page_len'])
        wiki_lat.append(r['lat'])
        wiki_lon.append(r['lon'])
        type_loc.append(r['type'])
        population.append(r['population'])

    df = pd.DataFrame(
        {'main_id' : main_id,
         'wiki_title': wiki_title,
         'wiki_lat': wiki_lat,
         'wiki_lon': wiki_lon,
         'page_len': page_len,
         'type_loc': type_loc,
         'population': population
        })
    return df

def gaz_to_geodataframe(df):
    gdf = gpd.GeoDataFrame(
        df, geometry=gpd.points_from_xy(df.wiki_lon, df.wiki_lat))

    poly  = gpd.GeoDataFrame.from_file('gb1900_analysis/shapefiles/GBR_adm/GBR_adm0.shp')
    point = gdf

    pointInPolys = sjoin(point, poly, how='left')
    grouped = pointInPolys.groupby('index_right')
    
    britdf = df.iloc[grouped.groups[0]]
    britdf.reset_index(drop=True)
    britdf.to_pickle("brit_wikigazetteer.pkl")
    
    return britdf

def find_british_altnames(cursorGaz, timer):
    print('Start altnames SQL query: {} seconds'.format(timer() - start_time))

    cursorGaz.execute("""
            SELECT altname.* FROM altname
            JOIN location ON location.id=altname.main_id
            WHERE lat > 50.0
            AND lat < 62.0
            AND lon > -14.0
            AND lon < 3.0
        """)
    results = cursorGaz.fetchall()
    
    dAltnames = dict()
    
    for r in results:
        if len(r['altname']) < 50:
            dAltnames[r['id']] = (r['altname'], r['source'], r['main_id'])

    return dAltnames

# %% [markdown]
# #### Locations dataframe

# %%
# locdf = find_british_locations(cursorGaz, timer)
# britdf = gaz_to_geodataframe(locdf)
# britdf.head()
britdf = pd.read_pickle("GIR2019/gb1900_analysis/brit_wikigazetteer.pkl")
britdf.head()
# Out:
#    wiki_id        wiki_title  wiki_lat  wiki_lon                  geometry
# 0  20       Aberdeenshire     57.1510  -2.12300   POINT (-2.123 57.151)
# 1  21       A._A._Milne       51.0900   0.10700   POINT (0.107 51.09)
# 4  48       Abbotsford_House  55.5997  -2.78194   POINT (-2.78194 55.5997)
# 5  59       Aberdeen          57.1500  -2.11000   POINT (-2.11 57.15)
# 6  99       Angus,_Scotland   56.6667  -2.91667   POINT (-2.91667 56.6667)

# %% [markdown]
# #### Altnames dataframe

# %%
dAltnames = find_british_altnames(cursorGaz, timer)

alt_id = []
main_id = []
altname = []
source = []
for r in dAltnames:
    main_id.append(dAltnames[r][2])
    alt_id.append(r)
    altname.append(dAltnames[r][0])
    source.append(dAltnames[r][1])

altdf = pd.DataFrame(
    {'alt_id' : alt_id,
     'main_id': main_id,
     'altname': altname,
     'source': source
    })
# Out:
# Start altnames SQL query: 48.58997783399991 seconds

# %%
altdf.shape
# Out:
# (224386, 4)

# %%
altdf = altdf.groupby("main_id")['altname'].apply(', '.join)
altdf.head()
# Out:
# main_id
# 20    Aberdeenshire, Aberdeen County, Swydd Aberdeen, Aberdeen, Aiberdeenshire, Contae Obar Deathain, Siorrachd Obar Dheathain, Aberdonensis, Coontae Aberdon
# 21    A. A. Milne
# 23    Azincourt, Asincurtis
# 25    Achill Island, Acaill, Achill, Wyspa Achill, Achill - Acaill, Curraun
# 48    Abbotsford House, Abbotsford, Clartyhole
# Name: altname, dtype: object

# %% [markdown]
# #### Joint locations and altnames dataframe

# %%
britdf = pd.merge(locdf, altdf, how='left', on='main_id')
britdf = britdf[britdf.altname.notnull()]
# britdf.head()

# Example of multiple altnames:
britdf[britdf['main_id'] == 20]
# Out:
#        main_id     wiki_title  wiki_lat  wiki_lon  page_len type_loc  \
# 64008  20       Aberdeenshire  57.151   -2.123     30952     adm2nd
#
#        population               geometry  \
# 64008 NaN          POINT (-2.123 57.151)
#
#                                                                                                                                                        altname
# 64008  Aberdeenshire, Aberdeen County, Swydd Aberdeen, Aberdeen, Aiberdeenshire, Contae Obar Deathain, Siorrachd Obar Dheathain, Aberdonensis, Coontae Aberdon

# %%
altdf.shape
# Out:
# (206134,)

# %% [markdown]
# ### Exploratory first step

# %%
l_altname = []
l_wiki_title = []
l_gb1900text = []
l_gb1900lat = []
l_gb1900lon = []
l_wikilat = []
l_wikilon = []
for index, row in britdf.iloc[180100:180200].iterrows():
    for altnwiki in row['altname'].split(","):
        altnwiki = altnwiki.strip()
        matches = gb1900df[(gb1900df['final_text'].str.contains(row['altname'], case=False)) & (gb1900df['latitude'] >= row['wiki_lat'] - 0.0) & (gb1900df['latitude'] <= row['wiki_lat'] + 0.1) & (gb1900df['longitude'] >= row['wiki_lon'] - 0.1) & (gb1900df['longitude'] <= row['wiki_lon'] + 0.1)]
        for imatch, irow in matches.iterrows():
            l_altname.append(altnwiki)
            l_wiki_title.append(row['wiki_title'])
            l_gb1900text.append(irow['final_text'])
            l_gb1900lat.append(irow['latitude'])
            l_gb1900lon.append(irow['longitude'])
            l_wikilat.append(row['wiki_lat'])
            l_wikilon.append(row['wiki_lon'])
        if matches.empty:
            l_altname.append(altnwiki)
            l_wiki_title.append(row['wiki_title'])
            l_gb1900text.append('')
            l_gb1900lat.append('')
            l_gb1900lon.append('')
            l_wikilat.append(row['wiki_lat'])
            l_wikilon.append(row['wiki_lon'])

matchdf = pd.DataFrame(
        {'altname' : l_altname,
         'wiki_title': l_wiki_title,
         'gb1900text': l_gb1900text,
         'gb1900lat': l_gb1900lat,
         'gb1900lon': l_gb1900lon,
         'wiki_lat': l_wikilat,
         'wiki_lon': l_wikilon
        })

# %%
matchdf.to_pickle("match09.pkl")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
matchdf = pd.read_pickle("match09.pkl")
matchdf
# Out:
#                                            altname  \
# 0    Copinsay Lighthouse
# 1    Deerness
# 2    Deerness
# 3    Toab
# 4    Tankerness Meal Mill
# 5    Tankerness Fishing Station
# 6    Tankerness
# 7
# 8    Canniemyre
# 9    Gate Piers Balfour Castle
# 10   Shapinsay Kirk
# 11   Balfour Burial Aisle South Churchyard
# 12   Balfour Castle
# 13   Balfour Castle Doocot
# 14
# 15   Shapinsay Meal Mill Ellwick
# 16   Shapinsay Lighthouse
# 17   Stone Lodge
# 18   Balfour Village The Smithy
# 19   Walls
# 20
# 21   Flotta
# 22   Flotta
# 23   Flotta
# 24   Flotta
# 25   Flotta
# 26   Walls
# 27   Walls
# 28   Walls
# 29   Walls
# 30   South Walls
# 31   South Walls
# 32
# 33   Hoy
# 34   Hoy
# 35   Melsetter Farm
# 36   King Street Church
# 37   East Road
# 38   Berstane Road
# 39   Harbour Street
# 40   Bignold Park Pavilion
# 41   Glaitness Road
# 42   Kirkwall Harbour
# 43   School Place
# 44   Watergate Street And Victoria Road
# 45   The Strynd Walls Including Store House
# 46   Palace Road And Watergate Street
# 47   Ayre Road
# 48   Kirkwall Bowling Green
# 49   Laing Street
# 50   Mill Street
# 51   Bridge Street
# 52
# 53   Dundas Crescent
# 54   The Strynd
# 55   Palace Road
# 56   Broad Street
# 57   Holm Road
# 58   Watergate
# 59   Victoria Street
# 60   Bignold Park Road
# 61   St Magnus Cathedral Green
# 62   Queen Street And Bridge Street Wynd
# 63   Berstane Doocot
# 64   Kirkwall Harbour Light
# 65   Wideford Farmhouse
# 66   Trumland House
# 67   Rousay
# 68   Rousay
# 69   Rousay
# 70   Egilsay
# 71   St. Magnus Church
# 72   Westness House Inner Westness
# 73   Cubbie Roo s Castle
# 74   Eynhallow Monastery
# 75   Old Wyre Kirk
# 76   Rousay Meal Mill Sourin
# 77   Holland Farm Including Micklegarth
# 78   Papa Westray War Memorial
# 79   Holland House
# 80   Mid House
# 81   Kirkhouse Cottage
# 82   Nouster Stores Including Pier
# 83   St Boniface Kirk
# 84   The Manse
# 85   Holland Dovecot
# 86   Holland
# 87   Graemsay
# 88   Hoy
# 89   Hoy
# 90   Hoy
# 91   Greaemsay Kirk Including Graveyard
# 92   Sandwick Kirk
# 93   Skaill Doocot
# 94   Nether Benzieclett
# 95   West Aith
# 96   Skaill House
# 97   Mill Of Range
# 98   Mill Of Skaill
# 99   Old Firth Manse Cursiter
# 100  Binscarth House
# 101  Firth Meal Mill Millquoy
# 102  Burness House
# 103  Stronsay
# 104  Stronsay
# 105  Stronsay
# 106  Stronsay
# 107  Stronsay
# 108  Stronsay
# 109  Stronsay
# 110  Stronsay
# 111  Stronsay
# 112  Sanson s Lane Farm House
# 113  Huip Farmhouse
# 114  Stronsay Meal Mill Lower Millfield
# 115  Lower Millfield Farm
# 116  Auskerry Lighthouse
# 117  Papa Stronsay House
# 118  Moncur Memorial Church
# 119  Heather View
# 120  Cleat Farm Including Doocot
# 121  Noup Head Lighthouse Including Perimeter Wall
# 122  Brough Farmhouse
# 123  Pierowall
# 124  Brough Farm
# 125  Pierowall Harbour
#
#                                                       wiki_title  \
# 0    List_of_listed_buildings_in_St_Andrews_And_Deerness,_Orkney
# 1    List_of_listed_buildings_in_St_Andrews_And_Deerness,_Orkney
# 2    List_of_listed_buildings_in_St_Andrews_And_Deerness,_Orkney
# 3    List_of_listed_buildings_in_St_Andrews_And_Deerness,_Orkney
# 4    List_of_listed_buildings_in_St_Andrews_And_Deerness,_Orkney
# 5    List_of_listed_buildings_in_St_Andrews_And_Deerness,_Orkney
# 6    List_of_listed_buildings_in_St_Andrews_And_Deerness,_Orkney
# 7    List_of_listed_buildings_in_St_Andrews_And_Deerness,_Orkney
# 8    List_of_listed_buildings_in_St_Andrews_And_Deerness,_Orkney
# 9    List_of_listed_buildings_in_Shapinsay,_Orkney
# 10   List_of_listed_buildings_in_Shapinsay,_Orkney
# 11   List_of_listed_buildings_in_Shapinsay,_Orkney
# 12   List_of_listed_buildings_in_Shapinsay,_Orkney
# 13   List_of_listed_buildings_in_Shapinsay,_Orkney
# 14   List_of_listed_buildings_in_Shapinsay,_Orkney
# 15   List_of_listed_buildings_in_Shapinsay,_Orkney
# 16   List_of_listed_buildings_in_Shapinsay,_Orkney
# 17   List_of_listed_buildings_in_Shapinsay,_Orkney
# 18   List_of_listed_buildings_in_Shapinsay,_Orkney
# 19   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 20   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 21   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 22   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 23   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 24   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 25   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 26   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 27   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 28   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 29   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 30   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 31   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 32   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 33   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 34   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 35   List_of_listed_buildings_in_Walls_And_Flotta,_Orkney
# 36   List_of_listed_buildings_in_Kirkwall,_Orkney
# 37   List_of_listed_buildings_in_Kirkwall,_Orkney
# 38   List_of_listed_buildings_in_Kirkwall,_Orkney
# 39   List_of_listed_buildings_in_Kirkwall,_Orkney
# 40   List_of_listed_buildings_in_Kirkwall,_Orkney
# 41   List_of_listed_buildings_in_Kirkwall,_Orkney
# 42   List_of_listed_buildings_in_Kirkwall,_Orkney
# 43   List_of_listed_buildings_in_Kirkwall,_Orkney
# 44   List_of_listed_buildings_in_Kirkwall,_Orkney
# 45   List_of_listed_buildings_in_Kirkwall,_Orkney
# 46   List_of_listed_buildings_in_Kirkwall,_Orkney
# 47   List_of_listed_buildings_in_Kirkwall,_Orkney
# 48   List_of_listed_buildings_in_Kirkwall,_Orkney
# 49   List_of_listed_buildings_in_Kirkwall,_Orkney
# 50   List_of_listed_buildings_in_Kirkwall,_Orkney
# 51   List_of_listed_buildings_in_Kirkwall,_Orkney
# 52   List_of_listed_buildings_in_Kirkwall,_Orkney
# 53   List_of_listed_buildings_in_Kirkwall,_Orkney
# 54   List_of_listed_buildings_in_Kirkwall,_Orkney
# 55   List_of_listed_buildings_in_Kirkwall,_Orkney
# 56   List_of_listed_buildings_in_Kirkwall,_Orkney
# 57   List_of_listed_buildings_in_Kirkwall,_Orkney
# 58   List_of_listed_buildings_in_Kirkwall,_Orkney
# 59   List_of_listed_buildings_in_Kirkwall,_Orkney
# 60   List_of_listed_buildings_in_Kirkwall,_Orkney
# 61   List_of_listed_buildings_in_Kirkwall,_Orkney
# 62   List_of_listed_buildings_in_Kirkwall,_Orkney
# 63   List_of_listed_buildings_in_Kirkwall_And_St_Ola,_Orkney
# 64   List_of_listed_buildings_in_Kirkwall_And_St_Ola,_Orkney
# 65   List_of_listed_buildings_in_Kirkwall_And_St_Ola,_Orkney
# 66   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 67   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 68   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 69   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 70   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 71   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 72   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 73   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 74   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 75   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 76   List_of_listed_buildings_in_Rousay_And_Egilsay,_Orkney
# 77   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 78   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 79   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 80   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 81   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 82   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 83   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 84   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 85   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 86   List_of_listed_buildings_in_Papa_Westray,_Orkney
# 87   List_of_listed_buildings_in_Hoy_and_Graemsay,_Orkney
# 88   List_of_listed_buildings_in_Hoy_and_Graemsay,_Orkney
# 89   List_of_listed_buildings_in_Hoy_and_Graemsay,_Orkney
# 90   List_of_listed_buildings_in_Hoy_and_Graemsay,_Orkney
# 91   List_of_listed_buildings_in_Hoy_and_Graemsay,_Orkney
# 92   List_of_listed_buildings_in_Sandwick,_Orkney
# 93   List_of_listed_buildings_in_Sandwick,_Orkney
# 113                                                             59.1583
# 114                                                             59.1151
# 115                                                             59.1156
# 116                                                             59.0259
# 117                                                             59.1481
# 118                                                             59.1118
# 119                                                             59.3164
# 120                                                             59.3044
# 121                                                             59.3311
# 122                                                             59.3098
# 123  BAY OF PIEROWALL                       59.3214  -2.97765   59.3195
# 124                                                             59.3103
# 125                                                             59.3236
#
#      wiki_lon
# 0   -2.67199
# 1   -2.79425
# 2   -2.79425
# 3   -2.80488
# 4   -2.84581
# 5   -2.83201
# 6   -2.79546
# 7   -2.79546
# 8   -2.85532
# 9   -2.91036
# 10  -2.86825
# 11  -2.86792
# 12  -2.91677
# 13  -2.91010
# 14  -2.91010
# 15  -2.89877
# 16  -2.90100
# 17  -2.91036
# 18  -2.90930
# 19  -3.26328
# 20  -3.26328
# 21  -3.10842
# 22  -3.10842
# 23  -3.10842
# 24  -3.10842
# 25  -3.10842
# 26  -3.22794
# 27  -3.22794
# 28  -3.22794
# 29  -3.22794
# 30  -3.19182
# 31  -3.20670
# 32  -3.20670
# 33  -3.19676
# 34  -3.19676
# 35  -3.26811
# 36  -2.95687
# 37  -2.95099
# 38  -2.94746
# 39  -2.96291
# 40  -2.95377
# 41  -2.97144
# 42  -2.95980
# 43  -2.95599
# 44  -2.95964
# 45  -2.95935
# 46  -2.95982
# 47  -2.96994
# 48  -2.95864
# 49  -2.95769
# 50  -2.95599
# 51  -2.95791
# 52  -2.95791
# 53  -2.95537
# 54  -2.95935
# 55  -2.95889
# 56  -2.96127
# 57  -2.95460
# 58  -2.95953
# 59  -2.96138
# 60  -2.95377
# 61  -2.96060
# 62  -2.95696
# 63  -2.92335
# 64  -2.96012
# 65  -2.93733
# 66  -3.00006
# 67  -3.06407
# 68  -3.06407
# 69  -3.06407
# 70  -2.91436
# 71  -2.93530
# 72  -3.07979
# 73  -2.97673
# 74  -3.12201
# 75  -2.97465
# 76  -2.98017
# 77  -2.90070
# 78  -2.90001
# 79  -2.89987
# 80  -2.88703
# 81  -2.89490
# 82  -2.88581
# 83  -2.90205
# 84  -2.89433
# 85  -2.90283
# 86  -2.89846
# 87  -3.31012
# 88  -3.32469
# 89  -3.32469
# 90  -3.32469
# 91  -3.29222
# 92  -3.33579
# 93  -3.33538
# 94  -3.25679
# 95  -3.31227
# 96  -3.33655
# 97  -3.28227
# 98  -3.33776
# 99  -3.08077
# 100 -3.13630
# 101 -3.12490
# 102 -3.06844
# 103 -2.59308
# 104 -2.59308
# 105 -2.59308
# 106 -2.59308
# 107 -2.59308
# 108 -2.59308
# 109 -2.59308
# 110 -2.59308
# 111 -2.59308
# 112 -2.60819
# 113 -2.63641
# 114 -2.59747
# 115 -2.59817
# 116 -2.57228
# 117 -2.58500
# 118 -2.60544
# 119 -2.99651
# 120 -2.94196
# 121 -3.07030
# 122 -2.96928
# 123 -2.99295
# 124 -2.96965
# 125 -2.97424

# %% [markdown]
# ### Close DB connection

# %%
# PostreSQL:
if(gazDB):
    cursorGaz.close()
    gazDB.close()
