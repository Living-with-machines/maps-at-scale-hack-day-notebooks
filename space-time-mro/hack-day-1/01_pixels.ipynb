# %% [markdown]
# # Proof by Pixel: Basic Image Analytics for Research on Historical Maps

# %% [markdown]
# ### outline
#
# - basics of how images are stored on a computer
# - python image processing libraries:
#     - open CV - more geared towards computer vision tasks
#     - Pillow - much faster for some basic processing
#
# #### basics
#
# - loading images
# - display images
# - basic metadata
#
# ### Pixels

# %%
from matplotlib import pyplot as plt
import cv2

# %%
image = cv2.imread(filename = "maps/101200764.27_01_01.jpg")

# %%
plt.imshow(image)
plt.title('Map with railway tracks')
plt.show()

# %%
image.size
# Out:
# 158331789

# %%
## Resize image
